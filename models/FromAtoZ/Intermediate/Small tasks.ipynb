# %%
chr(100)
# Out:
# 'd'

# %%
import os
for x in os.listdir("gwfonts/converted/train/AveriaLibre-Light"):
    print(x)
# Out:
# AveriaLibre-Light_85.png
# AveriaLibre-Light_52.png
# AveriaLibre-Light_53.png
# AveriaLibre-Light_84.png
# AveriaLibre-Light_90.png
# AveriaLibre-Light_86.png
# AveriaLibre-Light_51.png
# AveriaLibre-Light_79.png
# AveriaLibre-Light_78.png
# AveriaLibre-Light_50.png
# AveriaLibre-Light_87.png
# AveriaLibre-Light_83.png
# AveriaLibre-Light_97.png
# AveriaLibre-Light_68.png
# AveriaLibre-Light_54.png
# AveriaLibre-Light_55.png
# AveriaLibre-Light_69.png
# AveriaLibre-Light_82.png
# AveriaLibre-Light_80.png
# AveriaLibre-Light_57.png
# AveriaLibre-Light_56.png
# AveriaLibre-Light_81.png
# AveriaLibre-Light_122.png
# AveriaLibre-Light_121.png
# AveriaLibre-Light_109.png
# AveriaLibre-Light_108.png
# AveriaLibre-Light_120.png
# AveriaLibre-Light_118.png
# AveriaLibre-Light_119.png
# AveriaLibre-Light_103.png
# AveriaLibre-Light_117.png
# AveriaLibre-Light_116.png
# AveriaLibre-Light_102.png
# AveriaLibre-Light_114.png
# AveriaLibre-Light_100.png
# AveriaLibre-Light_101.png
# ...

# %%
from dataloaderAZ import GwFontsDataset

# %%
dataset = GwFontsDataset(True, ['a', 'A', 'c', 'e', '9'], 100, "gwfonts/converted/")

# %%
dataset.font_names[40]
# Out:
# 'TulpenOne-Regular'

# %%
x = dataset.__getitem__(40)
# Out:
# /usr/local/lib/python3.11/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
a = dataset.get_ordered_images("AnticSlab-Regular")

# %%
import matplotlib.pyplot as plt
import time

# %%
for j in range(62):
    tns = x[j]
    plt.imshow(tns.permute(1, 2, 0), cmap="gray")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 for j in range(62):
# ----> 2     tns = x[j]
#       3     plt.imshow(tns.permute(1, 2, 0), cmap="gray")
#       4     plt.show()
#
# IndexError: index 5 is out of bounds for dimension 0 with size 5

# %%
from torchvision import transforms

# %%
dataset.__getitem__(40).shape
# Out:
# torch.Size([5, 1, 80, 80])
